# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cell = pd.read_csv('cellwall.txt', sep='\t', header=None)
iron = pd.read_csv('iron.txt', sep='\t', header=None)
trans = pd.read_csv('translation.txt', sep='\t', header=None)

# %%
al
fig, ax = subplots(figsize=(2, 18))
ax.imshow(.values[:100])
